# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov8" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#
# <br>
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"/></a>
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/ultralytics/yolov8"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# <br>
#
# Welcome to the Ultralytics YOLOv8 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLOv8</a> is the latest version of the YOLO (You Only Look Once) AI models developed by <a href="https://ultralytics.com">Ultralytics</a>. This notebook serves as the starting point for exploring the various resources available to help you get started with YOLOv8 and understand its features and capabilities.
#
# YOLOv8 models are fast, accurate, and easy to use, making them ideal for various object detection and image segmentation tasks. They can be trained on large datasets and run on diverse hardware platforms, from CPUs to GPUs.
#
# We hope that the resources in this notebook will help you get the most out of YOLOv8. Please browse the YOLOv8 <a href="https://docs.ultralytics.com/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/ultralytics">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
#
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.180 🚀 Python-3.8.10 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12045MiB)
# Setup complete ✅ (16 CPUs, 15.5 GB RAM, 199.7/216.0 GB disk)

# %% [markdown]
# # 1. Predict
#
# YOLOv8 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLOv8 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 10.3MB/s]
# Ultralytics YOLOv8.0.180 🚀 Python-3.8.10 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12045MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://ultralytics.com/images/zidane.jpg to 'zidane.jpg'...
# 100%|████████████████████████████████████████| 165k/165k [00:00<00:00, 2.62MB/s]
# image 1/1 /home/jabv/ultralytics/examples/zidane.jpg: 384x640 2 persons, 1 tie, 42.1ms
# Speed: 1.5ms preprocess, 42.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /home/jabv/ultralytics/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/212889447-69e5bdf1-5800-4e29-835e-2ed2336dede2.jpg" width="600">

# %% [markdown]
# # 2. Val
# Validate a model's accuracy on the [COCO](https://docs.ultralytics.com/datasets/detect/coco/) dataset's `val` or `test` splits. The latest YOLOv8 [models](https://github.com/ultralytics/ultralytics#models) are downloaded automatically the first time they are used. See [YOLOv8 Val Docs](https://docs.ultralytics.com/modes/val/) for more information.

# %%
# Download COCO val
import torch
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d datasets && rm tmp.zip  # unzip

# %%
# Validate YOLOv8n on COCO8 val
# !yolo val model=yolov8n.pt data=coco8.yaml
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# Dataset 'coco8.yaml' images not found ⚠️, missing path '/content/datasets/coco8/images/val'
# Downloading https://ultralytics.com/assets/coco8.zip to '/content/datasets/coco8.zip'...
# 100% 433k/433k [00:00<00:00, 12.4MB/s]
# Unzipping /content/datasets/coco8.zip to /content/datasets...
# Dataset download success ✅ (0.7s), saved to /content/datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 17.5MB/s]
# val: Scanning /content/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<00:00, 276.04it/s]
# val: New cache created: /content/datasets/coco8/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:03<00:00,  3.84s/it]
#                    all          4         17      0.621      0.833      0.888       0.63
#                 person          4         10      0.721        0.5      0.519      0.269
#                    dog          4          1       0.37          1      0.995      0.597
#                  horse          4          2      0.751          1      0.995      0.631
#               elephant          4          2      0.505        0.5      0.828      0.394
#               umbrella          4          1      0.564          1      0.995      0.995
#           potted plant          4          1      0.814          1      0.995      0.895
# Speed: 0.3ms preprocess, 78.7ms inference, 0.0ms loss, 65.4ms postprocess per image
# Results saved to runs/detect/val

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://bit.ly/ultralytics_hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/yolov8/banner-integrations.png"/></a></p>
#
# Train YOLOv8 on [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/) datasets. See [YOLOv8 Train Docs](https://docs.ultralytics.com/modes/train/) for more information.

# %%
#@title Select YOLOv8 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir .

# %%
# Train YOLOv8n on COCO8 for 3 epochs
# !yolo train model=yolov8n.pt data=/home/jabv/Desktop/final_ds/data.yaml epochs=200 patience=20 imgsz=640 device=0 name=larc5000_yolo8n
# Out:
# New https://pypi.org/project/ultralytics/8.0.182 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.180 🚀 Python-3.8.10 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12045MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/home/jabv/Desktop/final_ds/data.yaml, epochs=200, patience=20, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=8, project=None, name=larc5000_yolo8n, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=/home/jabv/ultralytics/runs/detect/larc5000_yolo8n3
# Overriding model.yaml nc=80 with nc=9
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753067  ultralytics.nn.modules.head.Detect           [9, [64, 128, 256]]
# Model summary: 225 layers, 3012603 parameters, 3012587 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir /home/jabv/ultralytics/runs/detect/larc5000_yolo8n3', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/jabv/Desktop/final_ds/train/labels.cache... 4000 images, 6
# train: WARNING ⚠️ /home/jabv/Desktop/final_ds/train/images/1469.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2325]
# train: WARNING ⚠️ /home/jabv/Desktop/final_ds/train/images/2147.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.23]
# train: WARNING ⚠️ /home/jabv/Desktop/final_ds/train/images/232.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0356]
# train: WARNING ⚠️ /home/jabv/Desktop/final_ds/train/images/2753.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3375]
# train: WARNING ⚠️ /home/jabv/Desktop/final_ds/train/images/3209.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.159]
# train: WARNING ⚠️ /home/jabv/Desktop/final_ds/train/images/4151.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2275]
# train: WARNING ⚠️ /home/jabv/Desktop/final_ds/train/images/4520.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0037]
# train: WARNING ⚠️ /home/jabv/Desktop/final_ds/train/images/581.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0674]
# val: Scanning /home/jabv/Desktop/final_ds/valid/labels.cache... 500 images, 67 b
# val: WARNING ⚠️ /home/jabv/Desktop/final_ds/valid/images/1832.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1273]
# Plotting labels to /home/jabv/ultralytics/runs/detect/larc5000_yolo8n3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/jabv/ultralytics/runs/detect/larc5000_yolo8n3
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200      2.13G     0.8213      2.887      1.079         50        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.521      0.612      0.581      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/200      2.13G     0.7629      1.577      1.017         42        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.906      0.755      0.867      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/200      2.13G     0.7709      1.335      1.019         37        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.885      0.798      0.874      0.718
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/200      2.13G     0.7823      1.207      1.022         51        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.926      0.814      0.896      0.744
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/200      2.26G     0.7529      1.062      1.015         41        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.948      0.807      0.906      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/200      2.26G     0.7369     0.9897      1.011         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.965      0.841      0.927       0.78
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/200      2.26G      0.714     0.9104      1.002         30        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331       0.96      0.844      0.924      0.783
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/200      2.26G      0.708     0.8507     0.9973         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331       0.95      0.844      0.926       0.79
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/200      2.26G      0.697      0.818     0.9945         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.973      0.858      0.932      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/200      2.26G      0.684      0.794     0.9886         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.971      0.852       0.93      0.789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/200      2.26G     0.6767     0.7631      0.982         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.948      0.847      0.921      0.791
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/200      2.26G     0.6661     0.7387      0.978         37        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.968      0.884      0.944      0.812
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/200      2.26G      0.657     0.7268     0.9749         48        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.974      0.867      0.934        0.8
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/200      2.26G      0.657     0.7067     0.9774         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.978      0.879      0.944      0.817
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/200      2.26G      0.651     0.6979     0.9682         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.968      0.883      0.944      0.815
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/200      2.26G     0.6506     0.6915     0.9726         35        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.969      0.877      0.944      0.814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/200      2.26G     0.6436     0.6782     0.9696         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331       0.98      0.871      0.948      0.821
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/200      2.26G     0.6419     0.6782     0.9729         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.965      0.886      0.943      0.817
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/200      2.26G     0.6357     0.6578     0.9665         20        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.979      0.888       0.95      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/200      2.26G     0.6302      0.642     0.9644         37        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.975       0.89      0.948      0.821
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/200      2.26G     0.6287     0.6463     0.9617         44        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.978      0.896      0.951      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/200      2.26G     0.6271     0.6411     0.9628         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.979      0.895      0.951      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/200      2.26G     0.6271     0.6365     0.9654         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.979      0.892      0.951      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/200      2.26G     0.6214     0.6212     0.9617         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.977      0.891      0.948      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/200      2.26G     0.6226     0.6197     0.9605         41        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.982      0.893      0.953      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/200      2.26G     0.6135     0.6108     0.9575         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.973      0.902      0.953      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/200      2.26G     0.6156     0.6092     0.9577         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.975      0.899      0.952       0.83
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/200      2.26G     0.6179     0.6111     0.9603         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.983      0.893      0.951      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/200      2.26G     0.6093     0.5968     0.9576         49        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.986      0.897      0.951      0.825
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/200      2.26G     0.6113     0.5976     0.9582         51        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.976      0.905      0.955      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/200      2.26G     0.6078     0.5904     0.9526         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.985      0.898      0.955      0.836
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/200      2.26G     0.6009     0.5824     0.9506         48        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.975      0.903      0.953      0.836
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/200      2.26G     0.5979     0.5854     0.9499         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.975      0.898      0.953      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/200      2.26G     0.5954     0.5791     0.9498         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.988      0.896      0.957       0.84
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/200      2.26G     0.6008     0.5844     0.9512         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.986      0.899      0.955      0.835
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/200      2.26G     0.6004     0.5779     0.9512         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.982      0.908      0.954      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/200      2.26G      0.595     0.5635     0.9467         39        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331       0.98      0.906      0.958      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/200      2.26G     0.5927     0.5697     0.9492         52        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.989      0.899      0.958      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/200      2.26G     0.5958     0.5747     0.9486         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.979      0.901      0.954      0.842
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/200      2.26G     0.5912     0.5668     0.9516         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.981      0.907      0.956      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/200      2.26G     0.5898     0.5624     0.9445         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.984      0.897      0.957      0.842
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/200      2.26G     0.5852     0.5552     0.9433         52        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.988      0.902      0.957      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/200      2.26G     0.5837     0.5453     0.9429         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.985      0.901      0.955      0.842
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/200      2.26G     0.5869     0.5593      0.944         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.988      0.895      0.956      0.842
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/200      2.26G     0.5844     0.5555     0.9442         54        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.978      0.913      0.959      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/200      2.26G     0.5842     0.5471     0.9451         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.977       0.91      0.957      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/200      2.26G     0.5789     0.5423     0.9403         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331       0.98      0.908      0.958      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/200      2.26G     0.5748      0.536     0.9397         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.981      0.905      0.956      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/200      2.26G     0.5789      0.536     0.9409         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.984      0.913      0.958      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/200      2.26G     0.5744     0.5376     0.9355         39        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.975      0.917      0.962      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/200      2.26G      0.573      0.535     0.9387         39        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.978      0.916      0.959      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/200      2.26G     0.5721     0.5342     0.9371         23        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331       0.98      0.915      0.959      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/200      2.26G     0.5698     0.5315     0.9321         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.972      0.904      0.953      0.835
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/200      2.26G     0.5686     0.5276     0.9368         37        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.971      0.921      0.961      0.849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/200      2.26G     0.5709     0.5209     0.9364         37        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.984      0.909      0.958      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/200      2.26G     0.5673     0.5223      0.936         42        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.978      0.907      0.957      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/200      2.26G     0.5741     0.5297     0.9398         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.987      0.907      0.957      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/200      2.26G      0.564     0.5237     0.9319         37        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.979      0.912      0.957      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/200      2.26G     0.5672     0.5221     0.9356         64        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.982      0.908      0.959      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/200      2.26G     0.5624     0.5143     0.9317         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.993      0.905      0.961      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/200      2.26G     0.5686     0.5255     0.9348         46        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.983      0.917      0.959      0.849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/200      2.26G     0.5622     0.5147     0.9322         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.989      0.916      0.962      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/200      2.26G     0.5617     0.5123     0.9332         35        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.987      0.916      0.962       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/200      2.26G     0.5594     0.5042     0.9294         21        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.986      0.909      0.958      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/200      2.26G     0.5582     0.5081     0.9299         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.986       0.92      0.962      0.849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/200      2.26G     0.5583     0.5025     0.9307         50        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.988      0.916       0.96       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/200      2.26G      0.553     0.4981     0.9255         43        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.981       0.92      0.961       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/200      2.26G     0.5584     0.5038     0.9264         49        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.988      0.919       0.96       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/200      2.26G     0.5607     0.5032     0.9329         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.985       0.92      0.961      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/200      2.26G     0.5542     0.4984     0.9254         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.979      0.926      0.961      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/200      2.26G     0.5525     0.4977     0.9269         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.987      0.915      0.961      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/200      2.26G     0.5529     0.4949     0.9261         39        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.988       0.92       0.96       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/200      2.26G     0.5512     0.4876     0.9294         32        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.988      0.915      0.962      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/200      2.26G     0.5439     0.4897     0.9244         41        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.989      0.923       0.96       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/200      2.26G     0.5481     0.4922     0.9242         42        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.986      0.919      0.962      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/200      2.26G     0.5521     0.4959     0.9273         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.983      0.927      0.961      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/200      2.26G     0.5468     0.4903     0.9287         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.992      0.913      0.962      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/200      2.26G     0.5483     0.4857     0.9271         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.991      0.915      0.961      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/200      2.26G     0.5461     0.4877     0.9251         64        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.981      0.925      0.962      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/200      2.26G     0.5471     0.4865     0.9235         48        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331       0.99      0.921      0.962      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/200      2.26G     0.5461     0.4833     0.9202         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.989      0.917      0.961      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/200      2.26G     0.5437     0.4904      0.924         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.986      0.923      0.963      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/200      2.26G     0.5386     0.4711     0.9173         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.985      0.922      0.962      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/200      2.26G     0.5419     0.4785     0.9248         35        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.982      0.928      0.961      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/200      2.26G     0.5397     0.4791     0.9247         41        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.984      0.923      0.961       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/200      2.26G     0.5396     0.4782     0.9203         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.988       0.92      0.961      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/200      2.26G      0.536     0.4729     0.9195         46        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.988      0.916      0.964      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/200      2.26G     0.5377     0.4753     0.9226         54        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.982      0.922      0.961      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/200      2.26G     0.5335     0.4731     0.9225         37        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.987      0.917      0.959      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/200      2.26G     0.5351     0.4697     0.9201         32        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.977      0.926      0.961      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/200      2.26G     0.5317     0.4628      0.917         22        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331       0.99      0.915      0.963      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/200      2.26G     0.5294     0.4677     0.9174         39        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.985      0.922      0.961      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/200      2.26G     0.5372     0.4685     0.9225         48        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.975      0.924      0.963      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/200      2.26G     0.5252     0.4568     0.9183         32        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.977      0.926      0.963      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/200      2.26G     0.5308     0.4656     0.9196         62        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.981      0.925      0.963      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/200      2.26G     0.5298     0.4645     0.9198         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.991      0.923      0.963      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/200      2.26G     0.5249     0.4562     0.9168         21        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.981      0.924      0.963      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/200      2.26G     0.5278     0.4617     0.9183         32        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.989       0.92      0.964      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/200      2.26G     0.5196     0.4496     0.9135         35        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.981      0.929      0.964      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/200      2.26G     0.5276     0.4558     0.9153         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.982      0.924      0.964      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     101/200      2.26G     0.5306     0.4624     0.9185         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.988      0.919      0.961      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     102/200      2.26G     0.5225     0.4526     0.9179         62        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.986      0.919      0.963      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     103/200      2.26G       0.52      0.452     0.9142         61        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.977      0.932      0.962      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     104/200      2.26G     0.5241     0.4472     0.9153         46        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.981      0.928      0.963      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     105/200      2.26G     0.5163      0.451     0.9153         53        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.979      0.929      0.963      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     106/200      2.26G     0.5176     0.4502     0.9138         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.981      0.928      0.963      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     107/200      2.26G     0.5168     0.4505     0.9152         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.985      0.926      0.964      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     108/200      2.26G     0.5134     0.4462     0.9087         43        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.984      0.932      0.963      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     109/200      2.26G     0.5153     0.4508     0.9129         51        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.984      0.927      0.963      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     110/200      2.26G     0.5125     0.4381     0.9094         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331       0.98       0.93      0.963      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     111/200      2.26G     0.5148     0.4384     0.9154         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.989      0.923      0.963      0.858
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     112/200      2.26G     0.5161      0.446     0.9114         56        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.983      0.924      0.961      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     113/200      2.26G     0.5093     0.4319     0.9097         60        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.985      0.922      0.962      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     114/200      2.26G     0.5119     0.4437     0.9114         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331       0.99      0.921      0.961      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     115/200      2.26G     0.5085     0.4386     0.9089         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.988      0.925      0.962      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     116/200      2.26G     0.5071      0.426     0.9046         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.989      0.922      0.962      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     117/200      2.26G     0.5066     0.4302     0.9061         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.983      0.922      0.961      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     118/200      2.26G     0.5103     0.4348     0.9106         23        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.982      0.925      0.962      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     119/200      2.26G     0.5038     0.4305     0.9076         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.988      0.918      0.961      0.853
# Stopping training early as no improvement observed in last 20 epochs. Best results observed at epoch 99, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 119 epochs completed in 0.896 hours.
# Optimizer stripped from /home/jabv/ultralytics/runs/detect/larc5000_yolo8n3/weights/last.pt, 6.2MB
# Optimizer stripped from /home/jabv/ultralytics/runs/detect/larc5000_yolo8n3/weights/best.pt, 6.2MB
#
# Validating /home/jabv/ultralytics/runs/detect/larc5000_yolo8n3/weights/best.pt...
# Ultralytics YOLOv8.0.180 🚀 Python-3.8.10 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12045MiB)
# Model summary (fused): 168 layers, 3007403 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        499       1331      0.981      0.929      0.964      0.859
#                      A        499        149      0.989       0.94      0.973       0.86
#                      B        499        154      0.981      0.903      0.938      0.851
#                      C        499        128      0.983      0.928      0.965      0.873
#                      D        499        150       0.98       0.94      0.983      0.867
#                      E        499        148      0.981      0.912      0.954       0.85
#                      F        499        174      0.967       0.96      0.981      0.877
#                      G        499        143      0.993      0.933      0.968      0.853
#                      H        499        148      0.989      0.912      0.953      0.833
#                      I        499        137      0.961      0.934       0.96      0.871
# Speed: 0.3ms preprocess, 1.1ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/jabv/ultralytics/runs/detect/larc5000_yolo8n3
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # 4. Export
#
# Export a YOLOv8 model to any supported format below with the `format` argument, i.e. `format=onnx`. See [YOLOv8 Export Docs](https://docs.ultralytics.com/modes/export/) for more information.
#
# - 💡 ProTip: Export to [ONNX](https://onnx.ai/) or [OpenVINO](https://docs.openvino.ai/latest/index.html) for up to 3x CPU speedup.
# - 💡 ProTip: Export to [TensorRT](https://developer.nvidia.com/tensorrt) for up to 5x GPU speedup.
#
#
# | Format                                                             | `format` Argument | Model                     | Metadata | Arguments                                           |
# |--------------------------------------------------------------------|-------------------|---------------------------|----------|-----------------------------------------------------|
# | [PyTorch](https://pytorch.org/)                                    | -                 | `yolov8n.pt`              | ✅        | -                                                   |
# | [TorchScript](https://pytorch.org/docs/stable/jit.html)            | `torchscript`     | `yolov8n.torchscript`     | ✅        | `imgsz`, `optimize`                                 |
# | [ONNX](https://onnx.ai/)                                           | `onnx`            | `yolov8n.onnx`            | ✅        | `imgsz`, `half`, `dynamic`, `simplify`, `opset`     |
# | [OpenVINO](https://docs.openvino.ai/latest/index.html)             | `openvino`        | `yolov8n_openvino_model/` | ✅        | `imgsz`, `half`                                     |
# | [TensorRT](https://developer.nvidia.com/tensorrt)                  | `engine`          | `yolov8n.engine`          | ✅        | `imgsz`, `half`, `dynamic`, `simplify`, `workspace` |
# | [CoreML](https://github.com/apple/coremltools)                     | `coreml`          | `yolov8n.mlpackage`       | ✅        | `imgsz`, `half`, `int8`, `nms`                      |
# | [TF SavedModel](https://www.tensorflow.org/guide/saved_model)      | `saved_model`     | `yolov8n_saved_model/`    | ✅        | `imgsz`, `keras`                                    |
# | [TF GraphDef](https://www.tensorflow.org/api_docs/python/tf/Graph) | `pb`              | `yolov8n.pb`              | ❌        | `imgsz`                                             |
# | [TF Lite](https://www.tensorflow.org/lite)                         | `tflite`          | `yolov8n.tflite`          | ✅        | `imgsz`, `half`, `int8`                             |
# | [TF Edge TPU](https://coral.ai/docs/edgetpu/models-intro/)         | `edgetpu`         | `yolov8n_edgetpu.tflite`  | ✅        | `imgsz`                                             |
# | [TF.js](https://www.tensorflow.org/js)                             | `tfjs`            | `yolov8n_web_model/`      | ✅        | `imgsz`                                             |
# | [PaddlePaddle](https://github.com/PaddlePaddle)                    | `paddle`          | `yolov8n_paddle_model/`   | ✅        | `imgsz`                                             |
# | [ncnn](https://github.com/Tencent/ncnn)                            | `ncnn`            | `yolov8n_ncnn_model/`     | ✅        | `imgsz`, `half`                                     |

# %%
# !yolo export model=yolov8n.pt format=torchscript
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.10.6 torch-2.0.1+cu118 CPU (Intel Xeon 2.30GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# TorchScript: starting export with torch 2.0.1+cu118...
# TorchScript: export success ✅ 2.8s, saved as 'yolov8n.torchscript' (12.4 MB)
#
# Export complete (4.6s)
# Results saved to /content
# Predict:         yolo predict task=detect model=yolov8n.torchscript imgsz=640
# Validate:        yolo val task=detect model=yolov8n.torchscript imgsz=640 data=None
# Visualize:       https://netron.app

# %% [markdown]
# # 5. Python Usage
#
# YOLOv8 was reimagined using Python-first principles for the most seamless Python YOLO experience yet. YOLOv8 models can be loaded from a trained checkpoint or created from scratch. Then methods are used to train, val, predict, and export the model. See detailed Python usage examples in the [YOLOv8 Python Docs](https://docs.ultralytics.com/usage/python/).

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from scratch
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='coco128.yaml', epochs=3)  # train the model
results = model.val()  # evaluate model performance on the validation set
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
results = model.export(format='onnx')  # export the model to ONNX format

# %% [markdown]
# # 6. Tasks
#
# YOLOv8 can train, val, predict and export models for the most common tasks in vision AI: [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/). See [YOLOv8 Tasks Docs](https://docs.ultralytics.com/tasks/) for more information.
#
# <br><img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/im/banner-tasks.png">

# %% [markdown]
# ## 1. Detection
#
# YOLOv8 _detection_ models have no suffix and are the default YOLOv8 models, i.e. `yolov8n.pt` and are pretrained on COCO. See [Detection Docs](https://docs.ultralytics.com/tasks/detect/) for full details.

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='coco128.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 2. Segmentation
#
# YOLOv8 _segmentation_ models use the `-seg` suffix, i.e. `yolov8n-seg.pt` and are pretrained on COCO. See [Segmentation Docs](https://docs.ultralytics.com/tasks/segment/) for full details.

# %%
# Load YOLOv8n-seg, train it on COCO128-seg for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')  # load a pretrained YOLOv8n segmentation model
model.train(data='coco128-seg.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 3. Classification
#
# YOLOv8 _classification_ models use the `-cls` suffix, i.e. `yolov8n-cls.pt` and are pretrained on ImageNet. See [Classification Docs](https://docs.ultralytics.com/tasks/classify/) for full details.

# %%
# Load YOLOv8n-cls, train it on mnist160 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')  # load a pretrained YOLOv8n classification model
model.train(data='mnist160', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 4. Pose
#
# YOLOv8 _pose_ models use the `-pose` suffix, i.e. `yolov8n-pose.pt` and are pretrained on COCO Keypoints. See [Pose Docs](https://docs.ultralytics.com/tasks/pose/) for full details.

# %%
# Load YOLOv8n-pose, train it on COCO8-pose for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n-pose.pt')  # load a pretrained YOLOv8n classification model
model.train(data='coco8-pose.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# Git clone and run tests on updates branch
# !git clone https://github.com/ultralytics/ultralytics -b main
# %pip install -qe ultralytics

# %%
# Run tests (Git clone only)
# !pytest ultralytics/tests

# %%
# Validate multiple models
for x in 'nsmlx':
  # !yolo val model=yolov8{x}.pt data=coco.yaml
